# %%
query = """
SELECT
  ROW_NUMBER() OVER(ORDER BY g.postal_code) as  geography_key, *
FROM global_mart_retail_dev.silver.geography as g

"""
df = spark.sql(query)

# %%
df.limit(10).display()

# %%
df.write.mode("overwrite").format("delta").saveAsTable("global_mart_retail_dev.gold.dim_geography")

# %%
# %sql
SELECT * FROM global_mart_retail_dev.gold.dim_geography LIMIT 10
