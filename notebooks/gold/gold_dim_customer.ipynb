# %%
query = """
SELECT
  ROW_NUMBER() OVER(ORDER BY c.customer_id) as customer_key,
  *
FROM global_mart_retail_dev.silver.customer AS c

"""
df = spark.sql(query)

# %%
display(df)

# %%
df.limit(10).display()

# %%
df.write.mode("overwrite").format("delta").saveAsTable("global_mart_retail_dev.gold.dim_customer")

# %%
# %sql
SELECT * FROM global_mart_retail_dev.gold.dim_customer LIMIT 10
